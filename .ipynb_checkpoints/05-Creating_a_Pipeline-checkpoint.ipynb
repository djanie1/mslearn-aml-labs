# %% [markdown]
# # Creating an Azure Machine Learning Pipeline
#
# You can perform the various steps required to ingest data, train a model, and register the model individually by using the Azure ML SDK to run script-based experiments. However, in an enterprise environment it is common to encapsulate the sequence of discrete steps required to build a machine learning solution into a *pipeline* that can be run on one or more compute targets, either on-demand by a user, from an automated build process, or on a schedule.
#
# In this lab, you'll bring together all of these elements to create a simple pipeline that trains and registers a model.
#
# ## Connect to Your Workspace
#
# The first thing you need to do is to connect to your workspace using the Azure ML SDK.
#
# > **Note**: If the authenticated session with your Azure subscription has expired since you completed the previous exercise, you'll be prompted to reauthenticate.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.17.0 to work with ml-sdk

# %% [markdown]
# ## Prepare the Training Data
#
# You can use local data files to train a model, but when running training workloads automatically on cloud-based compute, it makes more sense to store the data centrally in the cloud and ingest it into the training script wherever it happens to be running.
#
# In this lab, you'll upload the training data to a *datastore* and define a *dataset* that can be used to access the data from a training script. For simplicity, you'll upload the data to the default datastore for your Azure Machine Learning workspace - this is an Azure Storage blob container that was created when you provisioned the workspace. In a real solution, you'd likely register a datastore that references the cloud location where you typically store your data. You'll then create a *tabular* dataset that references the CSV files you uploaded.

# %%
from azureml.core import Dataset

default_ds = ws.get_default_datastore()

if 'diabetes dataset' not in ws.datasets:
    default_ds.upload_files(files=['./data/diabetes.csv', './data/diabetes2.csv'], # Upload the diabetes csv files in /data
                        target_path='diabetes-data/', # Put it in a folder path in the datastore
                        overwrite=True, # Replace existing files of the same name
                        show_progress=True)

    #Create a tabular dataset from the path on the datastore (this may take a short while)
    tab_data_set = Dataset.Tabular.from_delimited_files(path=(default_ds, 'diabetes-data/*.csv'))

    # Register the tabular dataset
    try:
        tab_data_set = tab_data_set.register(workspace=ws, 
                                name='diabetes dataset',
                                description='diabetes data',
                                tags = {'format':'CSV'},
                                create_new_version=True)
        print('Dataset registered.')
    except Exception as ex:
        print(ex)
else:
    print('Dataset already registered.')
# Out:
# Dataset already registered.

# %% [markdown]
# ## Create Scripts for Pipeline Steps
#
# Now you're ready to start work on your pipeline. Pipelines consist of one or more *steps*, which can be Python scripts, or specialized steps like an Auto ML training estimator or a data transfer step that copies data from one location to another. Each step can run in its own compute context.
#
# In this exercise, you'll build a simple pipeline that contains an estimator step (to train a model) and a Python script step (to register the trained model). Start by creating a folder to contain the scripts for each step.

# %%
import os
# Create a folder for the pipeline step files
experiment_folder = 'diabetes_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# diabetes_pipeline

# %% [markdown]
# The first step will use an estimator to run a training script. The code in the following cell creates this script for you. Note that the script includes a parameter named **output_folder**, which references the folder where the trained model should be saved.

# %%
# %%writefile $experiment_folder/train_diabetes.py
# Import libraries
from azureml.core import Run
import argparse
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument('--output_folder', type=str, dest='output_folder', default="diabetes_model", help='output folder')
args = parser.parse_args()
output_folder = args.output_folder

# Get the experiment run context
run = Run.get_context()

# load the diabetes data (passed as an input dataset)
print("Loading Data...")
diabetes = run.input_datasets['diabetes_train'].to_pandas_dataframe()

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train adecision tree model
print('Training a decision tree model')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# Save the trained model
os.makedirs(output_folder, exist_ok=True)
output_path = output_folder + "/model.pkl"
joblib.dump(value=model, filename=output_path)

run.complete()
# Out:
# Overwriting diabetes_pipeline/train_diabetes.py

# %% [markdown]
# The script for the second step of the pipeline will load the model from where it was saved, and then register it in the workspace. It includes a single **model_folder** parameter that contains the path to the folder where the model was saved by the previous step.

# %%
# %%writefile $experiment_folder/register_diabetes.py
# Import libraries
import argparse
import joblib
from azureml.core import Workspace, Model, Run

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument('--model_folder', type=str, dest='model_folder', default="diabetes_model", help='model location')
args = parser.parse_args()
model_folder = args.model_folder

# Get the experiment run context
run = Run.get_context()

# load the model
print("Loading model from " + model_folder)
model_file = model_folder + "/model.pkl"
model = joblib.load(model_file)

Model.register(workspace=run.experiment.workspace,
               model_path = model_file,
               model_name = 'diabetes_model',
               tags={'Training context':'Pipeline'})

run.complete()
# Out:
# Overwriting diabetes_pipeline/register_diabetes.py

# %% [markdown]
# ## Prepare a Compute Environment for the Pipeline Steps
#
# The pipeline will eventually be published and run on-demand, so it needs a compute environment in which to run. In this exercise, you'll use the same compute for both steps, but it's important to realize that each step is run independently; so you could specify different compute contexts for each step if appropriate.
#
# First, you need a compute target. In this case, you create an Azure Machine Learning compute cluster in your workspace (or use an existing one if you have created it previously).
#
# > **Important**: Change *your-compute-cluster* to a unique name for your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "dj-cluster"

try:
    # Check for existing compute target
    pipeline_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        pipeline_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        pipeline_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %% [markdown]
# The compute will require a Python environment with the necessary package dependencies installed, so we'll create a run configuration.

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.runconfig import RunConfiguration

# Create a Python environment for the experiment
diabetes_env = Environment("diabetes-pipeline-env")
diabetes_env.python.user_managed_dependencies = False # Let Azure ML manage dependencies
diabetes_env.docker.enabled = True # Use a docker container

# Create a set of package dependencies
diabetes_packages = CondaDependencies.create(conda_packages=['scikit-learn','pandas'],
                                             pip_packages=['azureml-defaults','azureml-dataprep[pandas]'])

# Add the dependencies to the environment
diabetes_env.python.conda_dependencies = diabetes_packages

# Register the environment (just in case you want to use it again)
diabetes_env.register(workspace=ws)
registered_env = Environment.get(ws, 'diabetes-pipeline-env')

# Create a new runconfig object for the pipeline
pipeline_run_config = RunConfiguration()

# Use the compute you created above. 
pipeline_run_config.target = pipeline_cluster

# Assign the environment to the run configuration
pipeline_run_config.environment = registered_env

print ("Run configuration created.")
# Out:
# Run configuration created.

# %% [markdown]
# ## Create and Run a Pipeline
#
# Now you're ready to define and run the pipeline.
#
# First you need to define the steps for the pipeline, and any data references that need to passed between them. In this case, the first step must write the model to a folder that can be read from by the second step. Since the steps will be run on remote compute (and in fact, could each be run on different compute), the folder path must be passed as a data reference to a location in a datastore within the workspace. The **PipelineData** object is a special kind of data reference that is used to pass data from the output of one pipeline step to the input of another, creating a dependency between them. You'll create one and use it as the output for the first step and the input for the second step. Note that you also need to pass it as a script argument so your code can access the datastore location referenced by the data reference.

# %%
from azureml.pipeline.core import PipelineData
from azureml.pipeline.steps import PythonScriptStep, EstimatorStep
from azureml.train.estimator import Estimator

# Get the training dataset
diabetes_ds = ws.datasets.get("diabetes dataset")

# Create a PipelineData (temporary Data Reference) for the model folder
model_folder = PipelineData("model_folder", datastore=ws.get_default_datastore())

estimator = Estimator(source_directory=experiment_folder,
                        compute_target = pipeline_cluster,
                        environment_definition=pipeline_run_config.environment,
                        entry_script='train_diabetes.py')

# Step 1, run the estimator to train the model
train_step = EstimatorStep(name = "Train Model",
                           estimator=estimator, 
                           estimator_entry_script_arguments=['--output_folder', model_folder],
                           inputs=[diabetes_ds.as_named_input('diabetes_train')],
                           outputs=[model_folder],
                           compute_target = pipeline_cluster,
                           allow_reuse = True)

# Step 2, run the model registration script
register_step = PythonScriptStep(name = "Register Model",
                                source_directory = experiment_folder,
                                script_name = "register_diabetes.py",
                                arguments = ['--model_folder', model_folder],
                                inputs=[model_folder],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

print("Pipeline steps defined")
# Out:
# Pipeline steps defined

# %% [markdown]
# OK, now you're ready to build the pipeline from the steps you've defined and run it as an experiment.
#
# > **Note**: This may take a while. The training cluster must be started and configured with the Python environment before the scripts can be run. Now might be a good time to take a coffee break!

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline

# Construct the pipeline
pipeline_steps = [train_step, register_step]
pipeline = Pipeline(workspace = ws, steps=pipeline_steps)
print("Pipeline is built.")

# Create an experiment and run the pipeline
experiment = Experiment(workspace = ws, name = 'diabetes-training-pipeline')
pipeline_run = experiment.submit(pipeline, regenerate_outputs=True)
print("Pipeline submitted for execution.")
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Pipeline is built.
# Created step Train Model [2182626c][c9f2fb2a-deae-46b7-9776-6d68961b9931], (This step will run and generate new outputs)Created step Register Model [bba45c3e][e6f1e683-4704-4eea-b17d-cb9b5eaf7ec8], (This step will run and generate new outputs)
#
# Submitted PipelineRun 180f6fb4-11ca-4a48-9b87-7a526690e44e
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/180f6fb4-11ca-4a48-9b87-7a526690e44e?wsid=/subscriptions/146e2193-c08a-4ef7-8b11-3f0eab5bd09d/resourcegroups/dp100/workspaces/ml-sdk
# Pipeline submitted for execution.
# PipelineRunId: 180f6fb4-11ca-4a48-9b87-7a526690e44e
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/180f6fb4-11ca-4a48-9b87-7a526690e44e?wsid=/subscriptions/146e2193-c08a-4ef7-8b11-3f0eab5bd09d/resourcegroups/dp100/workspaces/ml-sdk
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: fac5fcc4-401d-47e5-a32c-c818d1418989
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/fac5fcc4-401d-47e5-a32c-c818d1418989?wsid=/subscriptions/146e2193-c08a-4ef7-8b11-3f0eab5bd09d/resourcegroups/dp100/workspaces/ml-sdk
# StepRun( Train Model ) Status: NotStarted
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2020/11/02 15:50:14 Downloading source code...
# 2020/11/02 15:50:21 Finished downloading source code
# 2020/11/02 15:50:21 Creating Docker network: acb_default_network, driver: 'bridge'
# 2020/11/02 15:50:21 Successfully set up Docker network: acb_default_network
# 2020/11/02 15:50:21 Setting up Docker configuration...
# 2020/11/02 15:50:22 Successfully set up Docker configuration
# 2020/11/02 15:50:22 Logging in to registry: f7c76944ad884b0a818d04344d16dd8f.azurecr.io
# 2020/11/02 15:50:24 Successfully logged into f7c76944ad884b0a818d04344d16dd8f.azurecr.io
# 2020/11/02 15:50:24 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/11/02 15:50:24 Scanning for dependencies...
# 2020/11/02 15:50:24 Successfully scanned dependencies
# 2020/11/02 15:50:24 Launching container with name: acb_step_0
# Sending build context to Docker daemon  60.93kB
#
# Step 1/15 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1@sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
# sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# StepRun( Train Model ) Status: Running
# Digest: sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1@sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
#  ---> 287916b809d9
# Step 2/15 : USER root
#  ---> Running in 76ba02975bb9
# Removing intermediate container 76ba02975bb9
#  ---> a00139c77b22
# Step 3/15 : RUN mkdir -p $HOME/.cache
#  ---> Running in 0210da3c3a92
# Removing intermediate container 0210da3c3a92
#  ---> 6172f9152311
# Step 4/15 : WORKDIR /
#  ---> Running in be1465fc5e80
# Removing intermediate container be1465fc5e80
#  ---> 95397e0113fe
# Step 5/15 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 525efc935ec1
# Step 6/15 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 9fa78986cb01
# Removing intermediate container 9fa78986cb01
#  ---> b19fea003f60
# Step 7/15 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 6105265ca048
# Step 8/15 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_bc7a5497187886ce45cda35273d17a4c -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 8bfb36201ae9
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
#
# threadpoolctl-2.1.0  | 16 KB     |            |   0%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# intel-openmp-2020.2  | 947 KB    |            |   0%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 1          |   1%
# mkl-2019.4           | 204.1 MB  | 3          |   4%
# mkl-2019.4           | 204.1 MB  | 6          |   7%
# mkl-2019.4           | 204.1 MB  | 8          |   9%
# mkl-2019.4           | 204.1 MB  | #1         |  11%
# mkl-2019.4           | 204.1 MB  | #3         |  13%
# mkl-2019.4           | 204.1 MB  | #5         |  16%
# mkl-2019.4           | 204.1 MB  | #8         |  18%
# mkl-2019.4           | 204.1 MB  | ##1        |  22%
# mkl-2019.4           | 204.1 MB  | ##4        |  24%
# mkl-2019.4           | 204.1 MB  | ##7        |  27%
# mkl-2019.4           | 204.1 MB  | ###1       |  32%
# mkl-2019.4           | 204.1 MB  | ###5       |  36%
# mkl-2019.4           | 204.1 MB  | ####       |  40%
# mkl-2019.4           | 204.1 MB  | ####3      |  44%
# mkl-2019.4           | 204.1 MB  | ####7      |  48%
# mkl-2019.4           | 204.1 MB  | #####1     |  51%
# mkl-2019.4           | 204.1 MB  | #####5     |  55%
# mkl-2019.4           | 204.1 MB  | #####9     |  59%
# mkl-2019.4           | 204.1 MB  | ######3    |  63%
# mkl-2019.4           | 204.1 MB  | ######7    |  67%
# mkl-2019.4           | 204.1 MB  | #######1   |  71%
# mkl-2019.4           | 204.1 MB  | #######5   |  75%
# mkl-2019.4           | 204.1 MB  | #######9   |  79%
# mkl-2019.4           | 204.1 MB  | ########3  |  83%
# mkl-2019.4           | 204.1 MB  | ########7  |  87%
# mkl-2019.4           | 204.1 MB  | #########  |  91%
# mkl-2019.4           | 204.1 MB  | #########4 |  95%
# mkl-2019.4           | 204.1 MB  | #########8 |  98%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# pandas-1.1.3         | 10.5 MB   |            |   0%
# pandas-1.1.3         | 10.5 MB   | ####2      |  43%
# pandas-1.1.3         | 10.5 MB   | ########## | 100%
#
# numpy-1.19.1         | 20 KB     |            |   0%
# numpy-1.19.1         | 20 KB     | ########## | 100%
#
# joblib-0.17.0        | 205 KB    |            |   0%
# joblib-0.17.0        | 205 KB    | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# scikit-learn-0.23.2  | 6.9 MB    |            |   0%
# scikit-learn-0.23.2  | 6.9 MB    | ########6  |  87%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# mkl_fft-1.2.0        | 164 KB    |            |   0%
# mkl_fft-1.2.0        | 164 KB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | #####2     |  52%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
# python-dateutil-2.8. | 224 KB    |            |   0%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# numpy-base-1.19.1    | 5.2 MB    |            |   0%
# numpy-base-1.19.1    | 5.2 MB    | ########9  |  90%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
#
# scipy-1.5.2          | 18.5 MB   |            |   0%
# scipy-1.5.2          | 18.5 MB   | ##2        |  23%
# scipy-1.5.2          | 18.5 MB   | ######5    |  65%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
#
# pytz-2020.1          | 239 KB    |            |   0%
# pytz-2020.1          | 239 KB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | ##3        |  24%
# python-3.6.2         | 27.0 MB   | #####1     |  52%
# python-3.6.2         | 27.0 MB   | #######9   |  79%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_bc7a5497187886ce45cda35273d17a4c/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.u69let3f.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults~=1.17.0
#   Downloading azureml_defaults-1.17.0-py3-none-any.whl (3.0 kB)
# Collecting azureml-dataprep[pandas]
#   Downloading azureml_dataprep-2.4.2-py3-none-any.whl (28.2 MB)
# Collecting azureml-core~=1.17.0
#   Downloading azureml_core-1.17.0-py3-none-any.whl (2.1 MB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.17.0
#   Downloading azureml_dataset_runtime-1.17.0-py3-none-any.whl (3.4 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting azure-identity<2.0.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting azureml-dataprep-rslex<1.3.0a,>=1.2.0dev0
#   Downloading azureml_dataprep_rslex-1.2.2-cp36-cp36m-manylinux2010_x86_64.whl (7.9 MB)
# Collecting azureml-dataprep-native<25.0.0,>=24.0.0
#   Downloading azureml_dataprep_native-24.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.17-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting pyarrow<2.0.0,>=0.17.0; extra == "pandas"
#   Downloading pyarrow-1.0.1-cp36-cp36m-manylinux2014_x86_64.whl (17.3 MB)
# Requirement already satisfied, skipping upgrade: pandas<2.0.0,>=0.23.4; extra == "pandas" in /azureml-envs/azureml_bc7a5497187886ce45cda35273d17a4c/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.u69let3f.requirements.txt (line 2)) (1.1.3)
# Requirement already satisfied, skipping upgrade: numpy<2.0.0,>=1.14.0; extra == "pandas" in /azureml-envs/azureml_bc7a5497187886ce45cda35273d17a4c/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.u69let3f.requirements.txt (line 2)) (1.19.1)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.19-py2.py3-none-any.whl (84 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.1.2-py3-none-any.whl (14 kB)
# Requirement already satisfied, skipping upgrade: pytz in /azureml-envs/azureml_bc7a5497187886ce45cda35273d17a4c/lib/python3.6/site-packages (from azureml-core~=1.17.0->azureml-defaults~=1.17.0->-r /azureml-environment-setup/condaenv.u69let3f.requirements.txt (line 1)) (2020.1)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.25-py2.py3-none-any.whl (12 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-1.4.1-py2.py3-none-any.whl (36 kB)
# Collecting PyJWT
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting pyopenssl<20.0.0
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
# Collecting ruamel.yaml>=0.15.35
#   Downloading ruamel.yaml-0.16.12-py2.py3-none-any.whl (111 kB)
# Collecting requests>=2.19.1
#   Downloading requests-2.24.0-py2.py3-none-any.whl (61 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.0-py2.py3-none-any.whl (28 kB)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /azureml-envs/azureml_bc7a5497187886ce45cda35273d17a4c/lib/python3.6/site-packages (from azureml-core~=1.17.0->azureml-defaults~=1.17.0->-r /azureml-environment-setup/condaenv.u69let3f.requirements.txt (line 1)) (2.8.1)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-3.2.1-cp35-abi3-manylinux2010_x86_64.whl (2.6 MB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.5-py2.py3-none-any.whl (55 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-10.3.0-py2.py3-none-any.whl (1.0 MB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting docker
#   Downloading docker-4.3.1-py2.py3-none-any.whl (145 kB)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied, skipping upgrade: six>=1.10 in /azureml-envs/azureml_bc7a5497187886ce45cda35273d17a4c/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.17.0->-r /azureml-environment-setup/condaenv.u69let3f.requirements.txt (line 1)) (1.15.0)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.6.0-py2.py3-none-any.whl (50 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.8.2-py2.py3-none-any.whl (122 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_bc7a5497187886ce45cda35273d17a4c/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.17.0->azureml-defaults~=1.17.0->-r /azureml-environment-setup/condaenv.u69let3f.requirements.txt (line 1)) (2020.6.20)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.4.3-py3-none-any.whl (21 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-2.0.0-py2.py3-none-any.whl (31 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting cffi!=1.11.3,>=1.8
#   Downloading cffi-1.14.3-cp36-cp36m-manylinux1_x86_64.whl (400 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (27 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.0-py3-none-any.whl (5.2 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Building wheels for collected packages: json-logging-py, fusepy, liac-arff
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=f082b0dac9fda8597c0c5cae74813b10d50406c80081b60b0a1039c748b1fe80
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=6d60da3701df4e5352a9c41fabdc1ff4cab321e2cbdb1d53dc050bb2823131d3
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11730 sha256=19164e92b0f6a2a3c8ca6598a4dcf05d88bb8e240ba09288684f64bcea03a5c5
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
# Successfully built json-logging-py fusepy liac-arff
# Installing collected packages: idna, urllib3, chardet, requests, oauthlib, requests-oauthlib, isodate, msrest, PyJWT, pycparser, cffi, cryptography, adal, msrestazure, azure-common, azure-mgmt-containerregistry, jeepney, SecretStorage, azure-graphrbac, contextlib2, jmespath, zipp, importlib-metadata, jsonpickle, pyopenssl, azure-mgmt-keyvault, ruamel.yaml.clib, ruamel.yaml, pathspec, azure-mgmt-authorization, pyasn1, ndg-httpsclient, azure-mgmt-storage, azure-mgmt-resource, backports.weakref, backports.tempfile, websocket-client, docker, azureml-core, configparser, msal, azure-core, portalocker, msal-extensions, azure-identity, azureml-dataprep-rslex, azureml-dataprep-native, distro, dotnetcore2, cloudpickle, pyarrow, azureml-dataprep, fusepy, azureml-dataset-runtime, MarkupSafe, Jinja2, click, itsdangerous, werkzeug, flask, applicationinsights, json-logging-py, dill, liac-arff, azureml-model-management-sdk, gunicorn, azureml-defaults
# Successfully installed Jinja2-2.11.2 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.1.2 adal-1.2.5 applicationinsights-0.11.9 azure-common-1.1.25 azure-core-1.8.2 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-10.3.0 azure-mgmt-storage-11.2.0 azureml-core-1.17.0 azureml-dataprep-2.4.2 azureml-dataprep-native-24.0.0 azureml-dataprep-rslex-1.2.2 azureml-dataset-runtime-1.17.0 azureml-defaults-1.17.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.3 chardet-3.0.4 click-7.1.2 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.2.1 dill-0.3.3 distro-1.5.0 docker-4.3.1 dotnetcore2-2.1.17 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 idna-2.10 importlib-metadata-2.0.0 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.4.3 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-1.4.1 liac-arff-2.5.0 msal-1.6.0 msal-extensions-0.2.2 msrest-0.6.19 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pathspec-0.8.0 portalocker-1.7.1 pyarrow-1.0.1 pyasn1-0.4.8 pycparser-2.20 pyopenssl-19.1.0 requests-2.24.0 requests-oauthlib-1.3.0 ruamel.yaml-0.16.12 ruamel.yaml.clib-0.2.2 urllib3-1.25.11 websocket-client-0.57.0 werkzeug-1.0.1 zipp-3.4.0
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_bc7a5497187886ce45cda35273d17a4c
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 8bfb36201ae9
#  ---> bf2d9e388f73
# Step 9/15 : ENV PATH /azureml-envs/azureml_bc7a5497187886ce45cda35273d17a4c/bin:$PATH
#  ---> Running in 3445bf5d2549
# Removing intermediate container 3445bf5d2549
#  ---> 92813012d998
# Step 10/15 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_bc7a5497187886ce45cda35273d17a4c
#  ---> Running in 55b4a22a8cf2
# Removing intermediate container 55b4a22a8cf2
#  ---> 1d0484c48716
# Step 11/15 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_bc7a5497187886ce45cda35273d17a4c/lib:$LD_LIBRARY_PATH
#  ---> Running in cdd43fc53994
# Removing intermediate container cdd43fc53994
#  ---> c201528fa0dd
# Step 12/15 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> f97e354401c6
# Step 13/15 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in b03024b4da6f
# Removing intermediate container b03024b4da6f
#  ---> 8e6e17dc8378
# Step 14/15 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 0358013b1d6e
# Removing intermediate container 0358013b1d6e
#  ---> 1ae942a17e75
# Step 15/15 : CMD ["bash"]
#  ---> Running in 0f3dfef7d04a
# Removing intermediate container 0f3dfef7d04a
#  ---> 4971fc9fb988
# Successfully built 4971fc9fb988
# Successfully tagged f7c76944ad884b0a818d04344d16dd8f.azurecr.io/azureml/azureml_bd401ac3c076a51c9311bc3a9f47d376:latest
# 2020/11/02 15:53:39 Successfully executed container: acb_step_0
# 2020/11/02 15:53:39 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/11/02 15:53:39 Pushing image: f7c76944ad884b0a818d04344d16dd8f.azurecr.io/azureml/azureml_bd401ac3c076a51c9311bc3a9f47d376:latest, attempt 1
# The push refers to repository [f7c76944ad884b0a818d04344d16dd8f.azurecr.io/azureml/azureml_bd401ac3c076a51c9311bc3a9f47d376]
# e175a0f7c82e: Preparing
# b9c70b021f18: Preparing
# 454e62cdf987: Preparing
# bef24db03631: Preparing
# 7fc3477c71ef: Preparing
# 141dd3b030e9: Preparing
# 13e378616f24: Preparing
# efc99d952c3d: Preparing
# 9e292a80b88a: Preparing
# 5e1805eb9eb5: Preparing
# 8dab94e6d05c: Preparing
# 2817caf0a082: Preparing
# aece08fd27fc: Preparing
# 4caea5ef1f0b: Preparing
# dcc0cc99372e: Preparing
# 87c128261339: Preparing
# 41a253a417e6: Preparing
# e06660e80cf4: Preparing
# 2817caf0a082: Waiting
# 141dd3b030e9: Waiting
# 13e378616f24: Waiting
# efc99d952c3d: Waiting
# aece08fd27fc: Waiting
# 9e292a80b88a: Waiting
# 4caea5ef1f0b: Waiting
# 5e1805eb9eb5: Waiting
# 8dab94e6d05c: Waiting
# dcc0cc99372e: Waiting
# 87c128261339: Waiting
# 41a253a417e6: Waiting
# e06660e80cf4: Waiting
# e175a0f7c82e: Pushed
# 454e62cdf987: Pushed
# bef24db03631: Pushed
# 7fc3477c71ef: Pushed
# 141dd3b030e9: Pushed
# 13e378616f24: Pushed
# efc99d952c3d: Pushed
# 9e292a80b88a: Pushed
# aece08fd27fc: Pushed
# 5e1805eb9eb5: Pushed
# 8dab94e6d05c: Pushed
# dcc0cc99372e: Pushed
# 2817caf0a082: Pushed
# 87c128261339: Pushed
# 41a253a417e6: Pushed
# 4caea5ef1f0b: Pushed
# e06660e80cf4: Pushed
# b9c70b021f18: Pushed
# latest: digest: sha256:dab6b294ccedab375fe055ac7a2dab33fe798f8ac7404ad40490547835a1de4d size: 4095
# 2020/11/02 15:55:57 Successfully pushed image: f7c76944ad884b0a818d04344d16dd8f.azurecr.io/azureml/azureml_bd401ac3c076a51c9311bc3a9f47d376:latest
# 2020/11/02 15:55:57 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 195.305422)
# 2020/11/02 15:55:57 Populating digests for step ID: acb_step_0...
# 2020/11/02 15:55:58 Successfully populated digests for step ID: acb_step_0
# 2020/11/02 15:55:58 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 137.689040)
# 2020/11/02 15:55:58 The following dependencies were found:
# 2020/11/02 15:55:58
# - image:
#     registry: f7c76944ad884b0a818d04344d16dd8f.azurecr.io
#     repository: azureml/azureml_bd401ac3c076a51c9311bc3a9f47d376
#     tag: latest
#     digest: sha256:dab6b294ccedab375fe055ac7a2dab33fe798f8ac7404ad40490547835a1de4d
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20200821.v1
#     digest: sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
#   git: {}
#
#
# Run ID: ca3 was successful after 5m45s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_9e022e2c8490363a8e1aae6a928f121796d058654b099a179e1295d94a61c945_d.txt
# ========================================================================================================================
# 2020-11-02T16:00:21Z Starting output-watcher...
# 2020-11-02T16:00:21Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2020-11-02T16:00:23Z Executing 'Copy ACR Details file' on 10.0.0.7
# 2020-11-02T16:00:23Z Copy ACR Details file succeeded on 10.0.0.7. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_bd401ac3c076a51c9311bc3a9f47d376
# 8e097b52bfb8: Pulling fs layer
# a613a9b4553c: Pulling fs layer
# acc000f01536: Pulling fs layer
# 73eef93b7466: Pulling fs layer
# d5a54c1fb97f: Pulling fs layer
# 1536f6ca931b: Pulling fs layer
# d7b631d130cb: Pulling fs layer
# 75ffe8dfb222: Pulling fs layer
# 86b4bf2f8d5f: Pulling fs layer
# 5335952fa8d3: Pulling fs layer
# 96fa3cc6fe10: Pulling fs layer
# e428dd9daa94: Pulling fs layer
# 0f222a06c18b: Pulling fs layer
# f09fb2b94158: Pulling fs layer
# de304a7d3704: Pulling fs layer
# e8a634388e42: Pulling fs layer
# 8276c148ec65: Pulling fs layer
# 58ac202feb76: Pulling fs layer
# 5335952fa8d3: Waiting
# 96fa3cc6fe10: Waiting
# e428dd9daa94: Waiting
# 0f222a06c18b: Waiting
# f09fb2b94158: Waiting
# de304a7d3704: Waiting
# 73eef93b7466: Waiting
# e8a634388e42: Waiting
# 8276c148ec65: Waiting
# 58ac202feb76: Waiting
# d5a54c1fb97f: Waiting
# 75ffe8dfb222: Waiting
# 86b4bf2f8d5f: Waiting
# d7b631d130cb: Waiting
# 1536f6ca931b: Waiting
# a613a9b4553c: Verifying Checksum
# a613a9b4553c: Download complete
# acc000f01536: Verifying Checksum
# acc000f01536: Download complete
# 73eef93b7466: Verifying Checksum
# 73eef93b7466: Download complete
# 8e097b52bfb8: Verifying Checksum
# 8e097b52bfb8: Download complete
# 1536f6ca931b: Verifying Checksum
# 1536f6ca931b: Download complete
# d5a54c1fb97f: Verifying Checksum
# d5a54c1fb97f: Download complete
# d7b631d130cb: Verifying Checksum
# d7b631d130cb: Download complete
# 75ffe8dfb222: Verifying Checksum
# 75ffe8dfb222: Download complete
# 5335952fa8d3: Verifying Checksum
# 5335952fa8d3: Download complete
# e428dd9daa94: Verifying Checksum
# e428dd9daa94: Download complete
# 96fa3cc6fe10: Verifying Checksum
# 96fa3cc6fe10: Download complete
# 86b4bf2f8d5f: Verifying Checksum
# 86b4bf2f8d5f: Download complete
# 0f222a06c18b: Verifying Checksum
# 0f222a06c18b: Download complete
# f09fb2b94158: Verifying Checksum
# f09fb2b94158: Download complete
# de304a7d3704: Verifying Checksum
# de304a7d3704: Download complete
# e8a634388e42: Verifying Checksum
# e8a634388e42: Download complete
# 58ac202feb76: Verifying Checksum
# 58ac202feb76: Download complete
# 8e097b52bfb8: Pull complete
# a613a9b4553c: Pull complete
# acc000f01536: Pull complete
# 73eef93b7466: Pull complete
# 8276c148ec65: Verifying Checksum
# 8276c148ec65: Download complete
# d5a54c1fb97f: Pull complete
# 1536f6ca931b: Pull complete
# d7b631d130cb: Pull complete
# 75ffe8dfb222: Pull complete
# 86b4bf2f8d5f: Pull complete
# 5335952fa8d3: Pull complete
# 96fa3cc6fe10: Pull complete
# e428dd9daa94: Pull complete
# 0f222a06c18b: Pull complete
# f09fb2b94158: Pull complete
# de304a7d3704: Pull complete
# e8a634388e42: Pull complete
# 8276c148ec65: Pull complete
# 58ac202feb76: Pull complete
# Digest: sha256:dab6b294ccedab375fe055ac7a2dab33fe798f8ac7404ad40490547835a1de4d
# Status: Downloaded newer image for f7c76944ad884b0a818d04344d16dd8f.azurecr.io/azureml/azureml_bd401ac3c076a51c9311bc3a9f47d376:latest
# f14ae768647b01580c7833ba1be6b001b4e219f85d3b7e520753e45e7d8f8fe0
# 2020/11/02 16:01:56 setuptask.go:390: Starting App Insight Logger for task:  containerSetup
# 2020/11/02 16:01:56 logger.go:297: Version: 3.0.01381.0008 Branch: .SourceBranch Commit: 9725c87
# 2020/11/02 16:01:56 utils.go:309: /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2020/11/02 16:01:56 logger.go:297: sshd inside container not required for job, skipping setup.
# 2020/11/02 16:01:56 appinsightlogger.go:40: All App Insights Logs was send successfully
# 2020-11-02T16:02:04Z Job environment preparation succeeded on 10.0.0.7. Output:
# >>>   2020/11/02 16:00:17 setuptask.go:390: Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2020/11/02 16:00:17 logger.go:297: Version: 3.0.01381.0008 Branch: .SourceBranch Commit: 9725c87
# >>>   2020/11/02 16:00:17 logger.go:297: runtime.GOOS linux
# >>>   2020/11/02 16:00:17 dynamicconfigs.go:70: Reading dyanamic configs
# >>>   2020/11/02 16:00:17 selfupdate.go:183: Container sas url: https://baiscriptseastusprod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=zEVUlJatOuK%2BQxpWiJMBWPX9cG4lMgbG9SHLlTdHrWo%3D
# >>>   2020/11/02 16:00:18 utils.go:692: Failed to read from file /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables, open /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables: no such file or directory
# >>>   2020/11/02 16:00:18 logger.go:297: [in autoUpgradeFromJobNodeSetup] Is Azsecpack installed false, isEnable false,
# >>>   2020/11/02 16:00:18 logger.go:297: azsecpack isEnable:false,turnoffaz:true
# >>>   2020/11/02 16:00:18 logger.go:297: [doTurnOffAzsecpack] output:   Active: inactive (dead)
# >>>   ,err:<nil>.
# >>>   2020/11/02 16:00:18 logger.go:297: OS patching disabled by dynamic configs. Skipping.
# >>>   2020/11/02 16:00:18 logger.go:297: DetonationChamber is not enabled on this subscription: 146e2193-c08a-4ef7-8b11-3f0eab5bd09d
# >>>   2020/11/02 16:00:18 logger.go:297: GPU count found: 0
# >>>   2020/11/02 16:00:18 logger.go:297: AMLComputeXDSEndpoint:  https://eastus-prodk8ds.batchai.core.windows.net
# >>>   2020/11/02 16:00:18 logger.go:297: AMLComputeXDSApiVersion:  2018-02-01
# >>>   2020/11/02 16:00:18 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/config
# >>>   2020/11/02 16:00:18 logger.go:297: This is not a aml-workstation (compute instance), current offer type: azureml. Starting identity responder as part of prepareJobEnvironment.
# >>>   2020/11/02 16:00:18 logger.go:297: Starting identity responder.
# >>>   2020/11/02 16:00:18 userlogger.go:47: Starting identity responder.
# >>>   2020/11/02 16:00:18 utils.go:321: Failed to open file /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/config/.batchai.IdentityResponder.envlist: open /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/config/.batchai.IdentityResponder.envlist: no such file or directory
# >>>   2020/11/02 16:00:18 logger.go:297: Logfile used for identity responder: /mnt/batch/tasks/workitems/21bd280d-73aa-4c47-93a8-d51cc31f9be9/job-1/fac5fcc4-401d-47e5-a_7ac86715-1407-4f54-a3b7-880ae1840ff7/IdentityResponderLog-tvmps_9e022e2c8490363a8e1aae6a928f121796d058654b099a179e1295d94a61c945_d.txt
# >>>   2020/11/02 16:00:18 userlogger.go:47: Logfile used for identity responder: /mnt/batch/tasks/workitems/21bd280d-73aa-4c47-93a8-d51cc31f9be9/job-1/fac5fcc4-401d-47e5-a_7ac86715-1407-4f54-a3b7-880ae1840ff7/IdentityResponderLog-tvmps_9e022e2c8490363a8e1aae6a928f121796d058654b099a179e1295d94a61c945_d.txt
# >>>   2020/11/02 16:00:18 logger.go:297: Started Identity Responder for job.
# >>>   2020/11/02 16:00:18 userlogger.go:47: Started Identity Responder for job.
# >>>   2020/11/02 16:00:18 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/wd
# >>>   2020/11/02 16:00:18 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/shared
# >>>   2020/11/02 16:00:18 logger.go:297: Mounting job level file systems
# >>>   2020/11/02 16:00:18 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/mounts
# >>>   2020/11/02 16:00:18 protocol.go:795: Attempting to read datastore credentials file: /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/config/.amlcompute.datastorecredentials
# >>>   2020/11/02 16:00:18 protocol.go:797: Datastore credentials file not found, skipping.
# >>>   2020/11/02 16:00:18 protocol.go:764: Attempting to read runtime sas tokens file: /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/config/.master.runtimesastokens
# >>>   2020/11/02 16:00:18 protocol.go:766: Runtime sas tokens file not found, skipping.
# >>>   2020/11/02 16:00:18 logger.go:297: No NFS configured
# >>>   2020/11/02 16:00:18 logger.go:297: No Azure File Shares configured
# >>>   2020/11/02 16:00:18 logger.go:297: Mounting blob file systems
# >>>   2020/11/02 16:00:18 logger.go:297: Blobfuse runtime version blobfuse 1.0.3
# >>>   2020/11/02 16:00:18 logger.go:297: Mounting azureml-blobstore-f7c76944-ad88-4b0a-818d-04344d16dd8f container from mlsdk1289217328 account at /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/mounts/workspaceblobstore
# >>>   2020/11/02 16:00:18 logger.go:297: Using Compute Identity to authenticate Blobfuse: false.
# >>>   2020/11/02 16:00:18 logger.go:297: Using Compute Identity to authenticate Blobfuse: false.
# >>>   2020/11/02 16:00:18 userlogger.go:47: Running following command: &{/bin/bash [bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/configs/workspaceblobstore.cfg --log-level=LOG_WARNING] []  <nil>   [] <nil> <nil> <nil> <nil> <nil> false [] [] [] [] <nil> <nil>}
# >>>   2020/11/02 16:00:18 userlogger.go:47: Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/mounts/workspaceblobstore
# >>>   2020/11/02 16:00:18 logger.go:297: Waiting for blobfs to be mounted at /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/mounts/workspaceblobstore
# >>>   2020/11/02 16:00:18 logger.go:297: Successfully mounted azureml-blobstore-f7c76944-ad88-4b0a-818d-04344d16dd8f container from mlsdk1289217328 account at /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/mounts/workspaceblobstore
# >>>   2020/11/02 16:00:18 logger.go:297: No unmanaged file systems configured
# >>>   2020/11/02 16:00:18 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/mounts/workspaceblobstore/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/azureml_compute_logs
# >>>   2020/11/02 16:00:21 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/mounts/workspaceblobstore/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/logs
# >>>   2020/11/02 16:00:21 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/mounts/workspaceblobstore/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/outputs
# >>>   2020/11/02 16:00:21 userlogger.go:47: Starting output-watcher...
# >>>   2020/11/02 16:00:21 logger.go:297: Start to pulling docker image: f7c76944ad884b0a818d04344d16dd8f.azurecr.io/azureml/azureml_bd401ac3c076a51c9311bc3a9f47d376
# >>>   2020/11/02 16:00:21 logger.go:297: Start pull docker image: f7c76944ad884b0a818d04344d16dd8f.azurecr.io
# >>>   2020/11/02 16:00:21 logger.go:297: Getting ACR Credentials from EMS
# >>>   2020/11/02 16:00:21 logger.go:297: Requesting XDS for registry details.
# >>>   2020/11/02 16:00:21 logger.go:297: Attempt 1 of http call to https://eastus-prodk8ds.batchai.core.windows.net/hosttoolapi/subscriptions/146e2193-c08a-4ef7-8b11-3f0eab5bd09d/resourceGroups/dp100/workspaces/ml-sdk/clusters/dj-cluster/nodes/tvmps_9e022e2c8490363a8e1aae6a928f121796d058654b099a179e1295d94a61c945_d?api-version=2018-02-01
# >>>   2020/11/02 16:00:23 logger.go:297: Attempt 1. XDS Api returned non-successful ErrorCode: Success
# >>>    ErrorMessage:
# >>>
# >>>   2020/11/02 16:00:23 logger.go:297: Got container registry details from credentials service for registry address: f7c76944ad884b0a818d04344d16dd8f.azurecr.io.
# >>>   2020/11/02 16:00:23 logger.go:297: Writing ACR Details to file...
# >>>   2020/11/02 16:00:23 logger.go:297: Copying ACR Details file to worker nodes...
# >>>   2020/11/02 16:00:23 userlogger.go:47: Executing 'Copy ACR Details file' on 10.0.0.7
# >>>   2020/11/02 16:00:23 userlogger.go:47: Copy ACR Details file succeeded on 10.0.0.7. Output:
# >>>   >>>
# >>>   >>>
# >>>   2020/11/02 16:00:23 logger.go:297: Successfully retrieved ACR Credentials from EMS.
# >>>   2020/11/02 16:00:23 logger.go:297: Container registry is ACR.
# >>>   2020/11/02 16:00:23 logger.go:297: start login to the docker registry
# >>>   2020/11/02 16:00:23 logger.go:297: Successfully logged into the docker registry.
# >>>   2020/11/02 16:00:23 logger.go:297: Start run pull docker image command
# >>>   2020/11/02 16:01:36 logger.go:297: Pull docker image succeeded.
# >>>   2020/11/02 16:01:36 logger.go:297: Pull docker image time: 1m14.544359334s
# >>>
# >>>   2020/11/02 16:01:36 logger.go:297: Docker Version that this nodes use are: 3.0.1
# >>>
# >>>   2020/11/02 16:01:36 utils.go:309: /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# >>>   2020/11/02 16:01:36 logger.go:297: Running Docker command: docker run --ulimit memlock=9223372036854775807 --ulimit nofile=262144:262144 --cap-add sys_ptrace --name fac5fcc4-401d-47e5-a32c-c818d1418989 -v /mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts -v /mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs -v /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared -v /mnt/batch/tasks/workitems/21bd280d-73aa-4c47-93a8-d51cc31f9be9/job-1/fac5fcc4-401d-47e5-a_7ac86715-1407-4f54-a3b7-880ae1840ff7/certs:/mnt/batch/tasks/workitems/21bd280d-73aa-4c47-93a8-d51cc31f9be9/job-1/fac5fcc4-401d-47e5-a_7ac86715-1407-4f54-a3b7-880ae1840ff7/certs -v /mnt/batch/tasks/startup:/mnt/batch/tasks/startup -v /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/mounts/workspaceblobstore/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/mounts/workspaceblobstore/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/azureml_compute_logs -v /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989:/mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989 -v /mnt/batch/tasks/workitems/21bd280d-73aa-4c47-93a8-d51cc31f9be9/job-1/fac5fcc4-401d-47e5-a_7ac86715-1407-4f54-a3b7-880ae1840ff7/wd:/mnt/batch/tasks/workitems/21bd280d-73aa-4c47-93a8-d51cc31f9be9/job-1/fac5fcc4-401d-47e5-a_7ac86715-1407-4f54-a3b7-880ae1840ff7/wd -v /opt/azureml:/opt/azureml:ro -w /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/wd --expose 23 --env-file /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/config/.batchai.envlist --shm-size 2g -d -it --privileged --net=host f7c76944ad884b0a818d04344d16dd8f.azurecr.io/azureml/azureml_bd401ac3c076a51c9311bc3a9f47d376
# >>>   2020/11/02 16:01:56 logger.go:297: Container ssh is not required for job type.
# >>>   2020/11/02 16:01:56 logger.go:297: runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/mounts/workspaceblobstore/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/azureml_compute_logs
# >>>   2020/11/02 16:01:56 logger.go:297: runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_bc7a5497187886ce45cda35273d17a4c/bin/python /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/mounts/workspaceblobstore/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"5a4c363d-5087-446b-926b-5e62a7ecdf18","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2020/11/02 16:01:56 logger.go:297: runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/mounts/workspaceblobstore/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/azureml_compute_logs/65_job_prep-tvmps_9e022e2c8490363a8e1aae6a928f121796d058654b099a179e1295d94a61c945_d.txt
# >>>   2020/11/02 16:01:56 logger.go:297: runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/mounts/workspaceblobstore/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/azureml_compute_logs/65_job_prep-tvmps_9e022e2c8490363a8e1aae6a928f121796d058654b099a179e1295d94a61c945_d.txt
# >>>   2020/11/02 16:01:56 logger.go:297: native cmd: cd /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/mounts/workspaceblobstore/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989;/azureml-envs/azureml_bc7a5497187886ce45cda35273d17a4c/bin/python /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/mounts/workspaceblobstore/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"5a4c363d-5087-446b-926b-5e62a7ecdf18","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2020/11/02 16:01:56 logger.go:297: runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2020/11/02 16:01:56 logger.go:297: runSpecialJobTask: Running cmd: &{/usr/bin/docker [docker exec -t fac5fcc4-401d-47e5-a32c-c818d1418989 bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;cd /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/mounts/workspaceblobstore/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989;/azureml-envs/azureml_bc7a5497187886ce45cda35273d17a4c/bin/python /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/mounts/workspaceblobstore/azureml/fac5fcc4-401d-47e5-a32c-c818d1418989-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"5a4c363d-5087-446b-926b-5e62a7ecdf18","PathStack":["."],"SnapshotEntityId":null}]'] []  <nil> <nil> <nil> [] <nil> <nil> <nil> <nil> <nil> false [] [] [] [] <nil> <nil>}
# >>>   2020/11/02 16:02:04 logger.go:297: runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2020/11/02 16:02:04 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:01:57.471840] Entering job preparation.
# >>>   2020/11/02 16:02:04 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:01:58.728453] Starting job preparation.
# >>>   2020/11/02 16:02:04 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:01:58.728496] Extracting the control code.
# >>>   2020/11/02 16:02:04 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:01:58.779506] fetching and extracting the control code on master node.
# >>>   2020/11/02 16:02:04 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:01:58.779556] Starting extract_project.
# >>>   2020/11/02 16:02:04 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:01:58.779601] Starting to extract zip file.
# >>>   2020/11/02 16:02:04 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:02:00.174887] Finished extracting zip file.
# >>>   2020/11/02 16:02:04 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:02:00.449278] Using urllib.request Python 3.0 or later
# >>>   2020/11/02 16:02:04 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:02:00.449336] Start fetching snapshots.
# >>>   2020/11/02 16:02:04 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:02:00.449375] Start fetching snapshot.
# >>>   2020/11/02 16:02:04 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:02:00.449389] Retrieving project from snapshot: 5a4c363d-5087-446b-926b-5e62a7ecdf18
# >>>   2020/11/02 16:02:04 logger.go:297: runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 51
# >>>   2020/11/02 16:02:04 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:02:01.095737] Finished fetching snapshot.
# >>>   2020/11/02 16:02:04 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:02:01.095859] Finished fetching snapshots.
# >>>   2020/11/02 16:02:04 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:02:01.095876] Finished extract_project.
# >>>   2020/11/02 16:02:04 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:02:01.120054] Finished fetching and extracting the control code.
# >>>   2020/11/02 16:02:04 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:02:01.123660] downloadDataStore - Download from datastores if requested.
# >>>   2020/11/02 16:02:04 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:02:01.125495] Start run_history_prep.
# >>>   2020/11/02 16:02:04 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:02:01.282392] Entering context manager injector.
# >>>   2020/11/02 16:02:04 logger.go:297: runSpecialJobTask: preparation: Acquired lockfile /tmp/fac5fcc4-401d-47e5-a32c-c818d1418989-datastore.lock to downloading input data references
# >>>   2020/11/02 16:02:04 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:02:02.815749] downloadDataStore completed
# >>>   2020/11/02 16:02:04 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:02:02.819952] Job preparation is complete.
# >>>   2020/11/02 16:02:04 appinsightlogger.go:40: All App Insights Logs was send successfully
# >>>   2020/11/02 16:02:04 logger.go:297: Process Exiting with Code:  0
# >>>
# 2020-11-02T16:02:04Z 127.0.0.1 slots=2 max-slots=2
# 2020-11-02T16:02:04Z launching Custom job
# Streaming azureml-logs/75_job_post-tvmps_9e022e2c8490363a8e1aae6a928f121796d058654b099a179e1295d94a61c945_d.txt
# ===============================================================================================================
# [2020-11-02T16:02:39.729189] Entering job release
# [2020-11-02T16:02:40.975901] Starting job release
# [2020-11-02T16:02:40.976574] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 358
# [2020-11-02T16:02:40.976883] job release stage : upload_datastore starting...
# [2020-11-02T16:02:40.979163] job release stage : start importing azureml.history._tracking in run_history_release.
# [2020-11-02T16:02:40.979197] job release stage : execute_job_release starting...
# [2020-11-02T16:02:40.986019] job release stage : copy_batchai_cached_logs starting...
# [2020-11-02T16:02:40.986063] job release stage : copy_batchai_cached_logs completed...
# [2020-11-02T16:02:40.987429] Entering context manager injector.
# [2020-11-02T16:02:41.351988] job release stage : upload_datastore completed...
# [2020-11-02T16:02:41.439777] job release stage : send_run_telemetry starting...
# [2020-11-02T16:02:41.724732] job release stage : execute_job_release completed...
# [2020-11-02T16:02:45.275394] job release stage : send_run_telemetry completed...
# [2020-11-02T16:02:45.275785] Job release is complete
#
# StepRun(Train Model) Execution Summary
# =======================================
# StepRun( Train Model ) Status: Finished
# {'runId': 'fac5fcc4-401d-47e5-a32c-c818d1418989', 'target': 'dj-cluster', 'status': 'Completed', 'startTimeUtc': '2020-11-02T16:00:16.927391Z', 'endTimeUtc': '2020-11-02T16:02:53.503321Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '5a4c363d-5087-446b-926b-5e62a7ecdf18', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'c9f2fb2a-deae-46b7-9776-6d68961b9931', 'azureml.nodeid': '2182626c', 'azureml.pipelinerunid': '180f6fb4-11ca-4a48-9b87-7a526690e44e', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '764086a8-17c8-400c-8e48-2fd356e1adef'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'diabetes_train', 'mechanism': 'Direct'}}], 'outputDatasets': [], 'runDefinition': {'script': 'train_diabetes.py', 'command': [], 'useAbsolutePath': False, 'arguments': ['--output_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'dj-cluster', 'dataReferences': {'model_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/fac5fcc4-401d-47e5-a32c-c818d1418989/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {'diabetes_train': {'dataLocation': {'dataset': {'id': '764086a8-17c8-400c-8e48-2fd356e1adef', 'name': None, 'version': '1'}, 'dataPath': None}, 'mechanism': 'Direct', 'environmentVariableName': 'diabetes_train', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'environment': {'name': 'diabetes-pipeline-env', 'version': '2', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.17.0', 'azureml-dataprep[pandas]']}, 'scikit-learn', 'pandas'], 'name': 'azureml_bc7a5497187886ce45cda35273d17a4c'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}}, 'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://mlsdk1289217328.blob.core.windows.net/azureml/ExperimentRun/dcid.fac5fcc4-401d-47e5-a32c-c818d1418989/azureml-logs/20_image_build_log.txt?sv=2019-02-02&sr=b&sig=UJEVdKPF6JtbImfDGTYnV0KbwhGDKJRKgR%2FcUNkrot8%3D&st=2020-11-02T15%3A56%3A02Z&se=2020-11-03T00%3A06%3A02Z&sp=r', 'azureml-logs/55_azureml-execution-tvmps_9e022e2c8490363a8e1aae6a928f121796d058654b099a179e1295d94a61c945_d.txt': 'https://mlsdk1289217328.blob.core.windows.net/a ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '180f6fb4-11ca-4a48-9b87-7a526690e44e', 'status': 'Completed', 'startTimeUtc': '2020-11-02T15:49:45.40751Z', 'endTimeUtc': '2020-11-02T16:06:01.44748Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlsdk1289217328.blob.core.windows.net/azureml/ExperimentRun/dcid.180f6fb4-11ca-4a48-9b87-7a526690e44e/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=jW5%2B2jbZZdbd6sI8Ac0cCzU240zkV9Dtor01RDh1QFA%3D&st=2020-11-02T15%3A56%3A06Z&se=2020-11-03T00%3A06%3A06Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlsdk1289217328.blob.core.windows.net/azureml/ExperimentRun/dcid.180f6fb4-11ca-4a48-9b87-7a526690e44e/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=Vryx1m2L3EdxJtzc4wt%2FcM0KzI0Xfx3ltRr3NqtaiwM%3D&st=2020-11-02T15%3A56%3A06Z&se=2020-11-03T00%3A06%3A06Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlsdk1289217328.blob.core.windows.net/azureml/ExperimentRun/dcid.180f6fb4-11ca-4a48-9b87-7a526690e44e/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=Dmjv8OnhNJ1a9U4xlyaKkJMhSc2QlxCCFBYMYP%2BdWnM%3D&st=2020-11-02T15%3A56%3A06Z&se=2020-11-03T00%3A06%3A06Z&sp=r'}}
# 'Finished'

# %% [markdown]
# The output from the pipeline experiment will be displayed as it runs. keep an eye on the kernel indicator at the top right of the page, when it turns from **&#9899;** to **&#9711;**, the code has finished running. You can also monitor pipeline runs in the **Experiments** page in [Azure Machine Learning studio](https://ml.azure.com).
#
# When the pipeline has finished, a new model should be registered with a *Training context* tag indicating it was trained in a pipeline. Run the following code to verify this.

# %%
from azureml.core import Model

for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# diabetes_model version: 7
# 	 Training context : Pipeline
#
#
# diabetes_model_automl version: 1
# 	 Training context : Auto ML
# 	 AUC : 0.9904812577250306
# 	 Accuracy : 0.9520809898762654
#
#
# diabetes_model version: 6
# 	 Training context : Inline Training
# 	 AUC : 0.8743619085526643
# 	 Accuracy : 0.8873333333333333
#
#
# diabetes_model version: 5
# 	 Training context : Parameterized SKLearn Estimator
# 	 AUC : 0.8483904671874223
# 	 Accuracy : 0.7736666666666666
#
#
# diabetes_model version: 4
# 	 Training context : Estimator
# 	 AUC : 0.8484929598487486
# 	 Accuracy : 0.774
#
#
# diabetes_mitigated_20 version: 1
#
#
# diabetes_mitigated_19 version: 1
#
#
# diabetes_mitigated_18 version: 1
#
#
# diabetes_mitigated_17 version: 1
#
#
# diabetes_mitigated_16 version: 1
#
#
# diabetes_mitigated_15 version: 1
#
#
# diabetes_mitigated_14 version: 1
#
#
# diabetes_mitigated_13 version: 1
#
#
# diabetes_mitigated_12 version: 1
#
#
# diabetes_mitigated_11 version: 1
#
#
# diabetes_mitigated_10 version: 1
#
#
# diabetes_mitigated_9 version: 1
#
#
# diabetes_mitigated_8 version: 1
#
#
# diabetes_mitigated_7 version: 1
#
#
# diabetes_mitigated_6 version: 1
#
#
# diabetes_mitigated_5 version: 1
#
#
# diabetes_mitigated_4 version: 1
#
#
# diabetes_mitigated_3 version: 1
#
#
# diabetes_mitigated_2 version: 1
#
#
# diabetes_mitigated_1 version: 1
#
#
# diabetes_unmitigated version: 1
#
#
# diabetes_classifier version: 1
#
#
# diabetes_model version: 3
# 	 Training context : Inline Training
# 	 AUC : 0.8790686103786257
# 	 Accuracy : 0.8906666666666667
#
#
# diabetes_model version: 2
# 	 Training context : Inline Training
# 	 AUC : 0.888068803690671
# 	 Accuracy : 0.9024444444444445
#
#
# diabetes_model version: 1
# 	 Training context : Inline Training
# 	 AUC : 0.879837305338574
# 	 Accuracy : 0.8923333333333333

# %% [markdown]
# ## Publish the Pipeline
#
# Now that you've created a pipeline and verified it works, you can publish it as a REST service.

# %%
published_pipeline = pipeline.publish(name="Diabetes_Training_Pipeline",
                                      description="Trains diabetes model",
                                      version="1.0")
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://eastus.api.azureml.ms/pipelines/v1.0/subscriptions/146e2193-c08a-4ef7-8b11-3f0eab5bd09d/resourceGroups/dp100/providers/Microsoft.MachineLearningServices/workspaces/ml-sdk/PipelineRuns/PipelineSubmit/31c5b60f-25f8-44f4-a965-5411a3b62bb7

# %% [markdown]
# To use the endpoint, client applications need to make a REST call over HTTP. This request must be authenticated, so an authorization header is required. A real application would require a service principal with which to be authenticated, but to test this out, we'll use the authorization header from your current connection to your Azure workspace, which you can get using the following code:

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Now you're ready to call the REST interface. The pipeline runs asynchronously, so you'll get an identifier back, which you can use to track the pipeline experiment as it runs:

# %%
import requests
experiment_name = 'Run-diabetes-pipeline'

response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": experiment_name})
run_id = response.json()["Id"]
run_id
# Out:
# 'e3dd2a24-05db-4fc3-bae7-2cb4725180f7'

# %% [markdown]
# Since you have the run ID, you can use it to wait for the run to complete.
#
# > **Note**: The pipeline should complete quickly, because each step was configured to allow output reuse. This was done primarily for convenience and to save time in this example. In reality, you'd likely want the first step to run every time in case the data has changed, and trigger the subsequent steps only if the output from step one changes.

# %%
from azureml.pipeline.core.run import PipelineRun

published_pipeline_run = PipelineRun(ws.experiments[experiment_name], run_id)
published_pipeline_run.wait_for_completion(show_output=True)
# Out:
# PipelineRunId: e3dd2a24-05db-4fc3-bae7-2cb4725180f7
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/Run-diabetes-pipeline/runs/e3dd2a24-05db-4fc3-bae7-2cb4725180f7?wsid=/subscriptions/146e2193-c08a-4ef7-8b11-3f0eab5bd09d/resourcegroups/dp100/workspaces/ml-sdk
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 2d8afc48-2317-4d48-b7e3-a44139bfd21c
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/Run-diabetes-pipeline/runs/2d8afc48-2317-4d48-b7e3-a44139bfd21c?wsid=/subscriptions/146e2193-c08a-4ef7-8b11-3f0eab5bd09d/resourcegroups/dp100/workspaces/ml-sdk
# StepRun( Train Model ) Status: NotStarted
#
# Streaming azureml-logs/55_azureml-execution-tvmps_c8a27d29c4f9c493c98c60f28dea3278ebc6fb0caaee1ab2727851153905c126_d.txt
# ========================================================================================================================
# 2020-11-02T16:06:50Z Starting output-watcher...
# 2020-11-02T16:06:50Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# StepRun( Train Model ) Status: Running
# 2020-11-02T16:06:51Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2020-11-02T16:06:51Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_bd401ac3c076a51c9311bc3a9f47d376
# 8e097b52bfb8: Already exists
# a613a9b4553c: Already exists
# acc000f01536: Already exists
# 73eef93b7466: Already exists
# d5a54c1fb97f: Already exists
# 1536f6ca931b: Already exists
# d7b631d130cb: Already exists
# 75ffe8dfb222: Already exists
# 86b4bf2f8d5f: Already exists
# 5335952fa8d3: Already exists
# 96fa3cc6fe10: Already exists
# e428dd9daa94: Already exists
# 0f222a06c18b: Pulling fs layer
# f09fb2b94158: Pulling fs layer
# de304a7d3704: Pulling fs layer
# e8a634388e42: Pulling fs layer
# 8276c148ec65: Pulling fs layer
# 58ac202feb76: Pulling fs layer
# e8a634388e42: Waiting
# 8276c148ec65: Waiting
# 58ac202feb76: Waiting
# 0f222a06c18b: Download complete
# 0f222a06c18b: Pull complete
# f09fb2b94158: Verifying Checksum
# f09fb2b94158: Download complete
# de304a7d3704: Verifying Checksum
# de304a7d3704: Download complete
# f09fb2b94158: Pull complete
# de304a7d3704: Pull complete
# e8a634388e42: Verifying Checksum
# e8a634388e42: Download complete
# e8a634388e42: Pull complete
# 58ac202feb76: Verifying Checksum
# 58ac202feb76: Download complete
# 8276c148ec65: Verifying Checksum
# 8276c148ec65: Download complete
# 8276c148ec65: Pull complete
# 58ac202feb76: Pull complete
# Digest: sha256:dab6b294ccedab375fe055ac7a2dab33fe798f8ac7404ad40490547835a1de4d
# Status: Downloaded newer image for f7c76944ad884b0a818d04344d16dd8f.azurecr.io/azureml/azureml_bd401ac3c076a51c9311bc3a9f47d376:latest
#
# Streaming azureml-logs/65_job_prep-tvmps_c8a27d29c4f9c493c98c60f28dea3278ebc6fb0caaee1ab2727851153905c126_d.txt
# ===============================================================================================================
# [2020-11-02T16:07:43.639625] Entering job preparation.
# [2020-11-02T16:07:45.503654] Starting job preparation.
# [2020-11-02T16:07:45.503696] Extracting the control code.
# [2020-11-02T16:07:45.571063] fetching and extracting the control code on master node.
# [2020-11-02T16:07:45.571126] Starting extract_project.
# [2020-11-02T16:07:45.571193] Starting to extract zip file.
# [2020-11-02T16:07:47.368252] Finished extracting zip file.
# [2020-11-02T16:07:47.928940] Using urllib.request Python 3.0 or later
# [2020-11-02T16:07:47.929020] Start fetching snapshots.
# [2020-11-02T16:07:47.929080] Start fetching snapshot.
# [2020-11-02T16:07:47.929103] Retrieving project from snapshot: 5a4c363d-5087-446b-926b-5e62a7ecdf18
# Starting the daemon thread to refresh tokens in background for process with pid = 51
# [2020-11-02T16:07:48.704461] Finished fetching snapshot.
# [2020-11-02T16:07:48.704516] Finished fetching snapshots.
# [2020-11-02T16:07:48.704532] Finished extract_project.
# [2020-11-02T16:07:48.728304] Finished fetching and extracting the control code.
# [2020-11-02T16:07:48.733235] Start run_history_prep.
# [2020-11-02T16:07:48.733409] downloadDataStore - Download from datastores if requested.
# [2020-11-02T16:07:48.878126] Entering context manager injector.
# Acquired lockfile /tmp/2d8afc48-2317-4d48-b7e3-a44139bfd21c-datastore.lock to downloading input data references
# [2020-11-02T16:07:50.452860] downloadDataStore completed
# [2020-11-02T16:07:50.458106] Job preparation is complete.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2020/11/02 16:07:51 logger.go:297: Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/info
# 2020/11/02 16:07:51 logger.go:297: Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# [2020-11-02T16:07:54.272784] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['train_diabetes.py', '--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/2d8afc48-2317-4d48-b7e3-a44139bfd21c/mounts/workspaceblobstore/azureml/2d8afc48-2317-4d48-b7e3-a44139bfd21c/model_folder'])
# Starting the daemon thread to refresh tokens in background for process with pid = 112
# Entering Run History Context Manager.
# Current directory:  /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/2d8afc48-2317-4d48-b7e3-a44139bfd21c/mounts/workspaceblobstore/azureml/2d8afc48-2317-4d48-b7e3-a44139bfd21c
# Preparing to call script [ train_diabetes.py ] with arguments: ['--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/2d8afc48-2317-4d48-b7e3-a44139bfd21c/mounts/workspaceblobstore/azureml/2d8afc48-2317-4d48-b7e3-a44139bfd21c/model_folder']
# After variable expansion, calling script [ train_diabetes.py ] with arguments: ['--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/2d8afc48-2317-4d48-b7e3-a44139bfd21c/mounts/workspaceblobstore/azureml/2d8afc48-2317-4d48-b7e3-a44139bfd21c/model_folder']
#
# Script type = None
# Loading Data...
# Training a decision tree model
# Accuracy: 0.896
# AUC: 0.8804451597547693
# Starting the daemon thread to refresh tokens in background for process with pid = 112
#
#
# [2020-11-02T16:08:14.875684] The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 900.0 seconds
# 2 items cleaning up...
# Cleanup took 0.16276836395263672 seconds
# [2020-11-02T16:08:15.527710] Finished context manager injector.
#
# Streaming azureml-logs/75_job_post-tvmps_c8a27d29c4f9c493c98c60f28dea3278ebc6fb0caaee1ab2727851153905c126_d.txt
# ===============================================================================================================
# [2020-11-02T16:08:23.270730] Entering job release
# [2020-11-02T16:08:24.556534] Starting job release
# [2020-11-02T16:08:24.557387] Logging experiment finalizing status in history service.
# [2020-11-02T16:08:24.557523] job release stage : upload_datastore starting...
# Starting the daemon thread to refresh tokens in background for process with pid = 338
# [2020-11-02T16:08:24.557834] job release stage : start importing azureml.history._tracking in run_history_release.
# [2020-11-02T16:08:24.558093] job release stage : execute_job_release starting...
# [2020-11-02T16:08:24.558302] job release stage : copy_batchai_cached_logs starting...
# [2020-11-02T16:08:24.558443] job release stage : copy_batchai_cached_logs completed...
# [2020-11-02T16:08:24.567103] Entering context manager injector.
# [2020-11-02T16:08:25.010445] job release stage : upload_datastore completed...
# [2020-11-02T16:08:25.298731] job release stage : execute_job_release completed...
# [2020-11-02T16:08:25.656635] job release stage : send_run_telemetry starting...
# [2020-11-02T16:08:27.792628] job release stage : send_run_telemetry completed...
# [2020-11-02T16:08:27.792955] Job release is complete
#
# StepRun(Train Model) Execution Summary
# =======================================
# StepRun( Train Model ) Status: Finished
# {'runId': '2d8afc48-2317-4d48-b7e3-a44139bfd21c', 'target': 'dj-cluster', 'status': 'Completed', 'startTimeUtc': '2020-11-02T16:06:50.161348Z', 'endTimeUtc': '2020-11-02T16:08:37.986712Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '5a4c363d-5087-446b-926b-5e62a7ecdf18', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'c9f2fb2a-deae-46b7-9776-6d68961b9931', 'azureml.nodeid': '2182626c', 'azureml.pipelinerunid': 'e3dd2a24-05db-4fc3-bae7-2cb4725180f7', 'azureml.pipelineid': '31c5b60f-25f8-44f4-a965-5411a3b62bb7', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '764086a8-17c8-400c-8e48-2fd356e1adef'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'diabetes_train', 'mechanism': 'Direct'}}], 'outputDatasets': [], 'runDefinition': {'script': 'train_diabetes.py', 'command': [], 'useAbsolutePath': False, 'arguments': ['--output_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'dj-cluster', 'dataReferences': {'model_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/2d8afc48-2317-4d48-b7e3-a44139bfd21c/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {'diabetes_train': {'dataLocation': {'dataset': {'id': '764086a8-17c8-400c-8e48-2fd356e1adef', 'name': None, 'version': '1'}, 'dataPath': None}, 'mechanism': 'Direct', 'environmentVariableName': 'diabetes_train', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'environment': {'name': 'diabetes-pipeline-env', 'version': '2', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.17.0', 'azureml-dataprep[pandas]']}, 'scikit-learn', 'pandas'], 'name': 'azureml_bc7a5497187886ce45cda35273d17a4c'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_c8a27d29c4f9c493c98c60f28dea3278ebc6fb0caaee1ab2727851153905c126_d.txt': 'https://mlsdk1289217328.blob.core.windows.net/azureml/ExperimentRun/dcid.2d8afc48-2317-4d48-b7e3-a44139bfd21c/azureml-logs/55_azureml-execution-tvmps_c8a27d29c4f9c493c98c60f28dea3278ebc6fb0caaee1ab2727851153905c126_d.txt?sv=2019-02-02&sr=b&sig=%2Flnn4JsVMveTEfN27Jxt79nL2AtLfw8JI5FFzqlEEhE%3D&st=2020-11-02 ...
# StepRunId: 31f2b22b-351c-4b3b-8360-18a3367786b4
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/Run-diabetes-pipeline/runs/31f2b22b-351c-4b3b-8360-18a3367786b4?wsid=/subscriptions/146e2193-c08a-4ef7-8b11-3f0eab5bd09d/resourcegroups/dp100/workspaces/ml-sdk
# StepRun( Register Model ) Status: NotStarted
# StepRun( Register Model ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_c8a27d29c4f9c493c98c60f28dea3278ebc6fb0caaee1ab2727851153905c126_d.txt
# ========================================================================================================================
# 2020-11-02T16:11:56Z Starting output-watcher...
# 2020-11-02T16:11:56Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2020-11-02T16:11:58Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2020-11-02T16:11:58Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_bd401ac3c076a51c9311bc3a9f47d376
# Digest: sha256:dab6b294ccedab375fe055ac7a2dab33fe798f8ac7404ad40490547835a1de4d
# Status: Image is up to date for f7c76944ad884b0a818d04344d16dd8f.azurecr.io/azureml/azureml_bd401ac3c076a51c9311bc3a9f47d376:latest
# e5f8ff58c54cbc45d35316b93bf3ca2091a43f35b60541243766190b5e090dd0
# 2020/11/02 16:12:00 setuptask.go:390: Starting App Insight Logger for task:  containerSetup
# 2020/11/02 16:12:00 logger.go:297: Version: 3.0.01381.0008 Branch: .SourceBranch Commit: 9725c87
# 2020/11/02 16:12:00 utils.go:309: /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2020/11/02 16:12:00 logger.go:297: sshd inside container not required for job, skipping setup.
# 2020/11/02 16:12:01 appinsightlogger.go:40: All App Insights Logs was send successfully
# 2020-11-02T16:12:08Z Job environment preparation succeeded on 10.0.0.4. Output:
# >>>   2020/11/02 16:11:52 setuptask.go:390: Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2020/11/02 16:11:52 logger.go:297: Version: 3.0.01381.0008 Branch: .SourceBranch Commit: 9725c87
# >>>   2020/11/02 16:11:52 logger.go:297: runtime.GOOS linux
# >>>   2020/11/02 16:11:52 dynamicconfigs.go:70: Reading dyanamic configs
# >>>   2020/11/02 16:11:52 selfupdate.go:183: Container sas url: https://baiscriptseastusprod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=zEVUlJatOuK%2BQxpWiJMBWPX9cG4lMgbG9SHLlTdHrWo%3D
# >>>   2020/11/02 16:11:52 utils.go:692: Failed to read from file /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables, open /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables: no such file or directory
# >>>   2020/11/02 16:11:52 logger.go:297: [in autoUpgradeFromJobNodeSetup] Is Azsecpack installed false, isEnable false,
# >>>   2020/11/02 16:11:52 logger.go:297: azsecpack isEnable:false,turnoffaz:true
# >>>   2020/11/02 16:11:52 logger.go:297: [doTurnOffAzsecpack] output:   Active: inactive (dead)
# >>>   ,err:<nil>.
# >>>   2020/11/02 16:11:52 logger.go:297: OS patching disabled by dynamic configs. Skipping.
# >>>   2020/11/02 16:11:52 logger.go:297: DetonationChamber is not enabled on this subscription: 146e2193-c08a-4ef7-8b11-3f0eab5bd09d
# >>>   2020/11/02 16:11:52 logger.go:297: GPU count found: 0
# >>>   2020/11/02 16:11:52 logger.go:297: AMLComputeXDSEndpoint:  https://eastus-prodk8ds.batchai.core.windows.net
# >>>   2020/11/02 16:11:52 logger.go:297: AMLComputeXDSApiVersion:  2018-02-01
# >>>   2020/11/02 16:11:52 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/config
# >>>   2020/11/02 16:11:52 logger.go:297: This is not a aml-workstation (compute instance), current offer type: azureml. Starting identity responder as part of prepareJobEnvironment.
# >>>   2020/11/02 16:11:52 logger.go:297: Starting identity responder.
# >>>   2020/11/02 16:11:52 userlogger.go:47: Starting identity responder.
# >>>   2020/11/02 16:11:52 utils.go:321: Failed to open file /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/config/.batchai.IdentityResponder.envlist: open /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/config/.batchai.IdentityResponder.envlist: no such file or directory
# >>>   2020/11/02 16:11:52 logger.go:297: Logfile used for identity responder: /mnt/batch/tasks/workitems/21bd280d-73aa-4c47-93a8-d51cc31f9be9/job-1/31f2b22b-351c-4b3b-8_cce8ef49-67f5-44a4-abff-60cfbb517082/IdentityResponderLog-tvmps_c8a27d29c4f9c493c98c60f28dea3278ebc6fb0caaee1ab2727851153905c126_d.txt
# >>>   2020/11/02 16:11:52 userlogger.go:47: Logfile used for identity responder: /mnt/batch/tasks/workitems/21bd280d-73aa-4c47-93a8-d51cc31f9be9/job-1/31f2b22b-351c-4b3b-8_cce8ef49-67f5-44a4-abff-60cfbb517082/IdentityResponderLog-tvmps_c8a27d29c4f9c493c98c60f28dea3278ebc6fb0caaee1ab2727851153905c126_d.txt
# >>>   2020/11/02 16:11:52 logger.go:297: Started Identity Responder for job.
# >>>   2020/11/02 16:11:52 userlogger.go:47: Started Identity Responder for job.
# >>>   2020/11/02 16:11:52 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/wd
# >>>   2020/11/02 16:11:52 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/shared
# >>>   2020/11/02 16:11:52 logger.go:297: Mounting job level file systems
# >>>   2020/11/02 16:11:52 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/mounts
# >>>   2020/11/02 16:11:52 protocol.go:795: Attempting to read datastore credentials file: /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/config/.amlcompute.datastorecredentials
# >>>   2020/11/02 16:11:52 protocol.go:797: Datastore credentials file not found, skipping.
# >>>   2020/11/02 16:11:52 protocol.go:764: Attempting to read runtime sas tokens file: /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/config/.master.runtimesastokens
# >>>   2020/11/02 16:11:52 protocol.go:766: Runtime sas tokens file not found, skipping.
# >>>   2020/11/02 16:11:52 logger.go:297: No NFS configured
# >>>   2020/11/02 16:11:52 logger.go:297: No Azure File Shares configured
# >>>   2020/11/02 16:11:52 logger.go:297: Mounting blob file systems
# >>>   2020/11/02 16:11:52 logger.go:297: Blobfuse runtime version blobfuse 1.0.3
# >>>   2020/11/02 16:11:52 logger.go:297: Mounting azureml-blobstore-f7c76944-ad88-4b0a-818d-04344d16dd8f container from mlsdk1289217328 account at /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/mounts/workspaceblobstore
# >>>   2020/11/02 16:11:52 logger.go:297: Using Compute Identity to authenticate Blobfuse: false.
# >>>   2020/11/02 16:11:52 logger.go:297: Using Compute Identity to authenticate Blobfuse: false.
# >>>   2020/11/02 16:11:52 userlogger.go:47: Running following command: &{/bin/bash [bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/configs/workspaceblobstore.cfg --log-level=LOG_WARNING] []  <nil>   [] <nil> <nil> <nil> <nil> <nil> false [] [] [] [] <nil> <nil>}
# >>>   2020/11/02 16:11:52 userlogger.go:47: Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/mounts/workspaceblobstore
# >>>   2020/11/02 16:11:52 logger.go:297: Waiting for blobfs to be mounted at /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/mounts/workspaceblobstore
# >>>   2020/11/02 16:11:53 logger.go:297: Successfully mounted azureml-blobstore-f7c76944-ad88-4b0a-818d-04344d16dd8f container from mlsdk1289217328 account at /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/mounts/workspaceblobstore
# >>>   2020/11/02 16:11:53 logger.go:297: No unmanaged file systems configured
# >>>   2020/11/02 16:11:53 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/mounts/workspaceblobstore/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/azureml_compute_logs
# >>>   2020/11/02 16:11:55 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/mounts/workspaceblobstore/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/logs
# >>>   2020/11/02 16:11:55 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/mounts/workspaceblobstore/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/outputs
# >>>   2020/11/02 16:11:56 userlogger.go:47: Starting output-watcher...
# >>>   2020/11/02 16:11:56 logger.go:297: Start to pulling docker image: f7c76944ad884b0a818d04344d16dd8f.azurecr.io/azureml/azureml_bd401ac3c076a51c9311bc3a9f47d376
# >>>   2020/11/02 16:11:56 logger.go:297: Start pull docker image: f7c76944ad884b0a818d04344d16dd8f.azurecr.io
# >>>   2020/11/02 16:11:56 logger.go:297: Getting ACR Credentials from EMS
# >>>   2020/11/02 16:11:56 logger.go:297: Requesting XDS for registry details.
# >>>   2020/11/02 16:11:56 logger.go:297: Attempt 1 of http call to https://eastus-prodk8ds.batchai.core.windows.net/hosttoolapi/subscriptions/146e2193-c08a-4ef7-8b11-3f0eab5bd09d/resourceGroups/dp100/workspaces/ml-sdk/clusters/dj-cluster/nodes/tvmps_c8a27d29c4f9c493c98c60f28dea3278ebc6fb0caaee1ab2727851153905c126_d?api-version=2018-02-01
# >>>   2020/11/02 16:11:58 logger.go:297: Attempt 1. XDS Api returned non-successful ErrorCode: Success
# >>>    ErrorMessage:
# >>>
# >>>   2020/11/02 16:11:58 logger.go:297: Got container registry details from credentials service for registry address: f7c76944ad884b0a818d04344d16dd8f.azurecr.io.
# >>>   2020/11/02 16:11:58 logger.go:297: Writing ACR Details to file...
# >>>   2020/11/02 16:11:58 logger.go:297: Copying ACR Details file to worker nodes...
# >>>   2020/11/02 16:11:58 userlogger.go:47: Executing 'Copy ACR Details file' on 10.0.0.4
# >>>   2020/11/02 16:11:58 userlogger.go:47: Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>   >>>
# >>>   >>>
# >>>   2020/11/02 16:11:58 logger.go:297: Successfully retrieved ACR Credentials from EMS.
# >>>   2020/11/02 16:11:58 logger.go:297: Container registry is ACR.
# >>>   2020/11/02 16:11:58 logger.go:297: start login to the docker registry
# >>>   2020/11/02 16:11:58 logger.go:297: Successfully logged into the docker registry.
# >>>   2020/11/02 16:11:58 logger.go:297: Start run pull docker image command
# >>>   2020/11/02 16:11:59 logger.go:297: Pull docker image succeeded.
# >>>   2020/11/02 16:11:59 logger.go:297: Pull docker image time: 2.802114649s
# >>>
# >>>   2020/11/02 16:11:59 logger.go:297: Docker Version that this nodes use are: 3.0.1
# >>>
# >>>   2020/11/02 16:11:59 utils.go:309: /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# >>>   2020/11/02 16:11:59 logger.go:297: Running Docker command: docker run --ulimit memlock=9223372036854775807 --ulimit nofile=262144:262144 --cap-add sys_ptrace --name 31f2b22b-351c-4b3b-8360-18a3367786b4 -v /mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts -v /mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs -v /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared -v /mnt/batch/tasks/workitems/21bd280d-73aa-4c47-93a8-d51cc31f9be9/job-1/31f2b22b-351c-4b3b-8_cce8ef49-67f5-44a4-abff-60cfbb517082/certs:/mnt/batch/tasks/workitems/21bd280d-73aa-4c47-93a8-d51cc31f9be9/job-1/31f2b22b-351c-4b3b-8_cce8ef49-67f5-44a4-abff-60cfbb517082/certs -v /mnt/batch/tasks/startup:/mnt/batch/tasks/startup -v /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/mounts/workspaceblobstore/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/mounts/workspaceblobstore/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/azureml_compute_logs -v /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4:/mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4 -v /mnt/batch/tasks/workitems/21bd280d-73aa-4c47-93a8-d51cc31f9be9/job-1/31f2b22b-351c-4b3b-8_cce8ef49-67f5-44a4-abff-60cfbb517082/wd:/mnt/batch/tasks/workitems/21bd280d-73aa-4c47-93a8-d51cc31f9be9/job-1/31f2b22b-351c-4b3b-8_cce8ef49-67f5-44a4-abff-60cfbb517082/wd -v /opt/azureml:/opt/azureml:ro -w /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/wd --expose 23 --env-file /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/config/.batchai.envlist --shm-size 2g -d -it --privileged --net=host f7c76944ad884b0a818d04344d16dd8f.azurecr.io/azureml/azureml_bd401ac3c076a51c9311bc3a9f47d376
# >>>   2020/11/02 16:12:01 logger.go:297: Container ssh is not required for job type.
# >>>   2020/11/02 16:12:01 logger.go:297: runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/mounts/workspaceblobstore/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/azureml_compute_logs
# >>>   2020/11/02 16:12:01 logger.go:297: runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_bc7a5497187886ce45cda35273d17a4c/bin/python /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/mounts/workspaceblobstore/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"5a4c363d-5087-446b-926b-5e62a7ecdf18","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2020/11/02 16:12:01 logger.go:297: runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/mounts/workspaceblobstore/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/azureml_compute_logs/65_job_prep-tvmps_c8a27d29c4f9c493c98c60f28dea3278ebc6fb0caaee1ab2727851153905c126_d.txt
# >>>   2020/11/02 16:12:01 logger.go:297: runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/mounts/workspaceblobstore/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/azureml_compute_logs/65_job_prep-tvmps_c8a27d29c4f9c493c98c60f28dea3278ebc6fb0caaee1ab2727851153905c126_d.txt
# >>>   2020/11/02 16:12:01 logger.go:297: native cmd: cd /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/mounts/workspaceblobstore/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4;/azureml-envs/azureml_bc7a5497187886ce45cda35273d17a4c/bin/python /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/mounts/workspaceblobstore/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"5a4c363d-5087-446b-926b-5e62a7ecdf18","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2020/11/02 16:12:02 logger.go:297: runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2020/11/02 16:12:02 logger.go:297: runSpecialJobTask: Running cmd: &{/usr/bin/docker [docker exec -t 31f2b22b-351c-4b3b-8360-18a3367786b4 bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;cd /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/mounts/workspaceblobstore/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4;/azureml-envs/azureml_bc7a5497187886ce45cda35273d17a4c/bin/python /mnt/batch/tasks/shared/LS_root/jobs/ml-sdk/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4/mounts/workspaceblobstore/azureml/31f2b22b-351c-4b3b-8360-18a3367786b4-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"5a4c363d-5087-446b-926b-5e62a7ecdf18","PathStack":["."],"SnapshotEntityId":null}]'] []  <nil> <nil> <nil> [] <nil> <nil> <nil> <nil> <nil> false [] [] [] [] <nil> <nil>}
# >>>   2020/11/02 16:12:07 logger.go:297: runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2020/11/02 16:12:07 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:12:02.808909] Entering job preparation.
# >>>   2020/11/02 16:12:07 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:12:03.999582] Starting job preparation.
# >>>   2020/11/02 16:12:07 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:12:03.999639] Extracting the control code.
# >>>   2020/11/02 16:12:07 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:12:04.075949] fetching and extracting the control code on master node.
# >>>   2020/11/02 16:12:07 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:12:04.076034] Starting extract_project.
# >>>   2020/11/02 16:12:07 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:12:04.076160] Starting to extract zip file.
# >>>   2020/11/02 16:12:07 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:12:05.244559] Finished extracting zip file.
# >>>   2020/11/02 16:12:07 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:12:05.518831] Using urllib.request Python 3.0 or later
# >>>   2020/11/02 16:12:07 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:12:05.518910] Start fetching snapshots.
# >>>   2020/11/02 16:12:07 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:12:05.518968] Start fetching snapshot.
# >>>   2020/11/02 16:12:07 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:12:05.518991] Retrieving project from snapshot: 5a4c363d-5087-446b-926b-5e62a7ecdf18
# >>>   2020/11/02 16:12:07 logger.go:297: runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 51
# >>>   2020/11/02 16:12:07 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:12:06.260805] Finished fetching snapshot.
# >>>   2020/11/02 16:12:07 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:12:06.260835] Finished fetching snapshots.
# >>>   2020/11/02 16:12:07 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:12:06.260852] Finished extract_project.
# >>>   2020/11/02 16:12:07 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:12:06.282405] Finished fetching and extracting the control code.
# >>>   2020/11/02 16:12:07 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:12:06.286916] Start run_history_prep.
# >>>   2020/11/02 16:12:07 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:12:06.287044] downloadDataStore - Download from datastores if requested.
# >>>   2020/11/02 16:12:07 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:12:06.364512] Entering context manager injector.
# >>>   2020/11/02 16:12:07 logger.go:297: runSpecialJobTask: preparation: Acquired lockfile /tmp/31f2b22b-351c-4b3b-8360-18a3367786b4-datastore.lock to downloading input data references
# >>>   2020/11/02 16:12:07 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:12:07.661290] downloadDataStore completed
# >>>   2020/11/02 16:12:07 logger.go:297: runSpecialJobTask: preparation: [2020-11-02T16:12:07.667340] Job preparation is complete.
# >>>   2020/11/02 16:12:08 appinsightlogger.go:40: All App Insights Logs was send successfully
# >>>   2020/11/02 16:12:08 logger.go:297: Process Exiting with Code:  0
# >>>
# 2020-11-02T16:12:08Z 127.0.0.1 slots=2 max-slots=2
# 2020-11-02T16:12:08Z launching Custom job
# Streaming azureml-logs/75_job_post-tvmps_c8a27d29c4f9c493c98c60f28dea3278ebc6fb0caaee1ab2727851153905c126_d.txt
# ===============================================================================================================
# [2020-11-02T16:12:21.031756] Entering job release
# [2020-11-02T16:12:22.159959] Starting job release
# [2020-11-02T16:12:22.172767] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 155
# [2020-11-02T16:12:22.173584] job release stage : upload_datastore starting...
# [2020-11-02T16:12:22.174045] job release stage : start importing azureml.history._tracking in run_history_release.
# [2020-11-02T16:12:22.174082] job release stage : execute_job_release starting...
# [2020-11-02T16:12:22.174585] job release stage : copy_batchai_cached_logs starting...
# [2020-11-02T16:12:22.174624] job release stage : copy_batchai_cached_logs completed...
# [2020-11-02T16:12:22.183704] Entering context manager injector.
# [2020-11-02T16:12:22.800967] job release stage : upload_datastore completed...
# [2020-11-02T16:12:22.836506] job release stage : send_run_telemetry starting...
# [2020-11-02T16:12:23.051301] job release stage : execute_job_release completed...
# [2020-11-02T16:12:26.035041] job release stage : send_run_telemetry completed...
# [2020-11-02T16:12:26.035558] Job release is complete
#
# StepRun(Register Model) Execution Summary
# ==========================================
# StepRun( Register Model ) Status: Finished
# {'runId': '31f2b22b-351c-4b3b-8360-18a3367786b4', 'target': 'dj-cluster', 'status': 'Completed', 'startTimeUtc': '2020-11-02T16:11:54.07577Z', 'endTimeUtc': '2020-11-02T16:12:33.809394Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '5a4c363d-5087-446b-926b-5e62a7ecdf18', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'e6f1e683-4704-4eea-b17d-cb9b5eaf7ec8', 'azureml.nodeid': 'bba45c3e', 'azureml.pipelinerunid': 'e3dd2a24-05db-4fc3-bae7-2cb4725180f7', 'azureml.pipelineid': '31c5b60f-25f8-44f4-a965-5411a3b62bb7', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'register_diabetes.py', 'command': [], 'useAbsolutePath': False, 'arguments': ['--model_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'dj-cluster', 'dataReferences': {'model_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/2d8afc48-2317-4d48-b7e3-a44139bfd21c/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'environment': {'name': 'diabetes-pipeline-env', 'version': '2', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.17.0', 'azureml-dataprep[pandas]']}, 'scikit-learn', 'pandas'], 'name': 'azureml_bc7a5497187886ce45cda35273d17a4c'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_c8a27d29c4f9c493c98c60f28dea3278ebc6fb0caaee1ab2727851153905c126_d.txt': 'https://mlsdk1289217328.blob.core.windows.net/azureml/ExperimentRun/dcid.31f2b22b-351c-4b3b-8360-18a3367786b4/azureml-logs/55_azureml-execution-tvmps_c8a27d29c4f9c493c98c60f28dea3278ebc6fb0caaee1ab2727851153905c126_d.txt?sv=2019-02-02&sr=b&sig=Fz1QCmC%2FH5wgjIoCMCfcB467OSqFxzcbUE1HGVVIIIQ%3D&st=2020-11-02T16%3A02%3A26Z&se=2020-11-03T00%3A12%3A26Z&sp=r', 'azureml-logs/65_job_prep-tvmps_c8a27d29c4f9c493c98c60f28dea3278ebc6fb0caaee1ab2727851153905c126_d.txt': 'https://mlsdk1289217328.blob.core.windows.net/azureml/ExperimentRun/dcid.31f2b22b-351c-4b3b-8360-18a3367786b4/azureml-logs/65_job_prep-tvmps_c8a27d29c4f9c493c98c60f28dea3278ebc6fb0caaee1ab2727851153905c126_d.txt?sv=2019-02-02&sr=b&sig=apqCFWd1PLltBUVnje6 ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'e3dd2a24-05db-4fc3-bae7-2cb4725180f7', 'status': 'Completed', 'startTimeUtc': '2020-11-02T16:06:30.684776Z', 'endTimeUtc': '2020-11-02T16:12:47.240758Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Unavailable', 'runType': 'HTTP', 'azureml.parameters': '{}', 'azureml.pipelineid': '31c5b60f-25f8-44f4-a965-5411a3b62bb7'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlsdk1289217328.blob.core.windows.net/azureml/ExperimentRun/dcid.e3dd2a24-05db-4fc3-bae7-2cb4725180f7/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=0W6%2FfEqfV1mNfe8%2FfGk5GFYUx2h1qDo2POOSluV7GSA%3D&st=2020-11-02T16%3A02%3A48Z&se=2020-11-03T00%3A12%3A48Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlsdk1289217328.blob.core.windows.net/azureml/ExperimentRun/dcid.e3dd2a24-05db-4fc3-bae7-2cb4725180f7/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=VVVxWU0hOlFXMJOAAN1PcG7PwDO55kXhOGjKKouwW7s%3D&st=2020-11-02T16%3A02%3A48Z&se=2020-11-03T00%3A12%3A48Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlsdk1289217328.blob.core.windows.net/azureml/ExperimentRun/dcid.e3dd2a24-05db-4fc3-bae7-2cb4725180f7/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=H19tF%2B75msLA6c4r3pKQ7hhCE37iDQ2Fgr%2BRPBleMeo%3D&st=2020-11-02T16%3A02%3A48Z&se=2020-11-03T00%3A12%3A48Z&sp=r'}}
# 'Finished'

# %% [markdown]
# This is a simple example, designed to demonstrate the principle. In reality, you could build more sophisticated logic into the pipeline steps - for example, evaluating the model against some test data to calculate a performance metric like AUC or accuracy, comparing the metric to that of any previously registered versions of the model, and only registering the new model if it performs better.
#
# You can use the [Azure Machine Learning extension for Azure DevOps](https://marketplace.visualstudio.com/items?itemName=ms-air-aiagility.vss-services-azureml) to combine Azure ML pipelines with Azure DevOps pipelines (yes, it *is* confusing that they have the same name!) and integrate model retraining into a *continuous integration/continuous deployment (CI/CD)* process. For example you could use an Azure DevOps *build* pipeline to trigger an Azure ML pipeline that trains and registers a model, and when the model is registered it could trigger an Azure Devops *release* pipeline that deploys the model as a web service, along with the application or service that consumes the model.
